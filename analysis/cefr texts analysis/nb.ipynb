# %% [markdown]
# Load Data
# https://www.kaggle.com/datasets/amontgomerie/cefr-levelled-english-texts

# %%
import pandas as pd
cefr_texts = pd.read_csv("./cefr_leveled_texts.csv")
cefr_texts.head(5)
# Out:
#                                                 text label
# 0  Hi!\nI've been meaning to write for ages and f...    B2
# 1  ﻿It was not so much how hard people found the ...    B2
# 2  Keith recently came back from a trip to Chicag...    B2
# 3  The Griffith Observatory is a planetarium, and...    B2
# 4  -LRB- The Hollywood Reporter -RRB- It's offici...    B2

# %% [markdown]
# Data preprocessing

# %%
import re

def preprocessing(text: str) -> str:
    text = text.lower()
    text = re.sub(r"-[a-z]+-","", text)
    text = text.replace("\n", " ")
    text = re.sub(r"\s+"," ", text)
    return text

cefr_texts.text = cefr_texts.text.apply(lambda x: preprocessing(x))
cefr_texts.head(5)
# Out:
#                                                 text label
# 0  hi! i've been meaning to write for ages and fi...    B2
# 1  ﻿it was not so much how hard people found the ...    B2
# 2  keith recently came back from a trip to chicag...    B2
# 3  the griffith observatory is a planetarium, and...    B2
# 4   the hollywood reporter it's official: amc's t...    B2

# %%
cefr_texts.label.value_counts()/len(cefr_texts)
# Out:
# label
# A1    0.192771
# B2    0.191432
# A2    0.182062
# C1    0.161312
# B1    0.137216
# C2    0.135207
# Name: count, dtype: float64

# %%
import os
import sys
base_dir = os.path.abspath(os.path.join(os.getcwd(), '../../src'))
os.chdir(base_dir)
sys.path.append(base_dir)

# %%
from res.wordsDegree.WordsDegree import get_degrees
from res.materials_VOC import CEFR_DICTIONARY_DF
from collections import Counter
from preprocessing.voc import voc_1_preprocessed_text
# Out:
# Start making general dict
# [nltk_data] Downloading package wordnet to /home/qw1n/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/qw1n/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# VOC 1 Func definition

# %%
import tqdm

def voc_1(text: str) -> tuple[Counter, float, int]:
    preprocessed_text, words_count = voc_1_preprocessed_text(text=text, stemming=False)
    cerf_dict = CEFR_DICTIONARY_DF
    cerf_levels, undefined = get_degrees(preprocessed_text)
    for token in undefined:
        if token in cerf_dict.headword.values:
            cerf_levels.append(cerf_dict[cerf_dict.headword == token].CEFR.values[0])
        else:
            cerf_levels.append("A1")
    cerf_counter = Counter(cerf_levels)
    return cerf_counter, len(preprocessed_text) / words_count, len(preprocessed_text)

features = pd.DataFrame(columns=["uniq", "words_a1", "words_a2", "words_b1", "words_b2", "words_c1", "words_c2", "text_cefr"])

for i in tqdm.trange(len(cefr_texts)):
    counter, uniq, uniq_count = voc_1(cefr_texts.text.values[i])
    row = {
        "uniq": uniq, 
        "words_a1": counter["A1"]/uniq_count, 
        "words_a2": counter["A2"]/uniq_count, 
        "words_b1": counter["B1"]/uniq_count, 
        "words_b2": counter["B2"]/uniq_count, 
        "words_c1": counter["C1"]/uniq_count, 
        "words_c2": counter["C2"]/uniq_count, 
        "text_cefr": cefr_texts.label.values[i]
    }
    features.loc[len(features)] = row
features.head(5)
# Out:
# 100%|██████████| 1494/1494 [12:14<00:00,  2.04it/s]
#        uniq  words_a1  words_a2  words_b1  words_b2  words_c1  words_c2  \
# 0  0.353982  0.606250  0.200000  0.106250  0.075000  0.006250  0.006250
# 1  0.352584  0.379310  0.228448  0.150862  0.185345  0.051724  0.004310
# 2  0.395745  0.408602  0.193548  0.225806  0.161290  0.010753  0.000000
# 3  0.393103  0.429825  0.166667  0.175439  0.157895  0.061404  0.008772
# 4  0.413374  0.573529  0.139706  0.102941  0.139706  0.036765  0.007353
#
#   text_cefr
# 0        B2
# 1        B2
# 2        B2
# 3        B2
# 4        B2

# %% [markdown]
# Features columns:
# uniq - unique words proportion;
# words_* - proportion of * level words from unique;
# text_cefr - CEFR level of text;

# %% [markdown]
# CEFR Level as 1..6 values

# %%
features_cefr_as_num = features.copy()
cefr_to_num = {
    'A1': 1,
    'A2': 2,
    'B1': 3,
    'B2': 4,
    'C1': 5,
    'C2': 6
}

features_cefr_as_num['text_cefr'] = features['text_cefr'].map(cefr_to_num)
features_cefr_as_num.corr()
# Out:
#                uniq  words_a1  words_a2  words_b1  words_b2  words_c1  \
# uniq       1.000000 -0.205286 -0.018430  0.082227  0.260154  0.096546
# words_a1  -0.205286  1.000000 -0.369729 -0.577213 -0.762104 -0.511128
# words_a2  -0.018430 -0.369729  1.000000 -0.045488 -0.047032 -0.143426
# words_b1   0.082227 -0.577213 -0.045488  1.000000  0.232315  0.156899
# words_b2   0.260154 -0.762104 -0.047032  0.232315  1.000000  0.378525
# words_c1   0.096546 -0.511128 -0.143426  0.156899  0.378525  1.000000
# words_c2   0.112037 -0.251865 -0.068190  0.108819  0.253723  0.221890
# text_cefr  0.346841 -0.699266 -0.005509  0.342485  0.693839  0.531615
#
#            words_c2  text_cefr
# uniq       0.112037   0.346841
# words_a1  -0.251865  -0.699266
# words_a2  -0.068190  -0.005509
# words_b1   0.108819   0.342485
# words_b2   0.253723   0.693839
# words_c1   0.221890   0.531615
# words_c2   1.000000   0.334225
# text_cefr  0.334225   1.000000

# %% [markdown]
# CEFR Levels as onehot values

# %%
features_cefr_as_num = features.copy()
cefr_to_num = {
    'A1': 1,
    'A2': 0,
    'B1': 0,
    'B2': 0,
    'C1': 0,
    'C2': 0
}

features_cefr_as_num['text_cefr'] = features['text_cefr'].map(cefr_to_num)
features_cefr_as_num.corr()
# Out:
#                uniq  words_a1  words_a2  words_b1  words_b2  words_c1  \
# uniq       1.000000 -0.205286 -0.018430  0.082227  0.260154  0.096546
# words_a1  -0.205286  1.000000 -0.369729 -0.577213 -0.762104 -0.511128
# words_a2  -0.018430 -0.369729  1.000000 -0.045488 -0.047032 -0.143426
# words_b1   0.082227 -0.577213 -0.045488  1.000000  0.232315  0.156899
# words_b2   0.260154 -0.762104 -0.047032  0.232315  1.000000  0.378525
# words_c1   0.096546 -0.511128 -0.143426  0.156899  0.378525  1.000000
# words_c2   0.112037 -0.251865 -0.068190  0.108819  0.253723  0.221890
# text_cefr -0.223974  0.484070 -0.038494 -0.301166 -0.461041 -0.252806
#
#            words_c2  text_cefr
# uniq       0.112037  -0.223974
# words_a1  -0.251865   0.484070
# words_a2  -0.068190  -0.038494
# words_b1   0.108819  -0.301166
# words_b2   0.253723  -0.461041
# words_c1   0.221890  -0.252806
# words_c2   1.000000  -0.168215
# text_cefr -0.168215   1.000000

# %%
features_cefr_as_num = features.copy()
cefr_to_num = {
    'A1': 0,
    'A2': 1,
    'B1': 0,
    'B2': 0,
    'C1': 0,
    'C2': 0
}

features_cefr_as_num['text_cefr'] = features['text_cefr'].map(cefr_to_num)
features_cefr_as_num.corr()
# Out:
#                uniq  words_a1  words_a2  words_b1  words_b2  words_c1  \
# uniq       1.000000 -0.205286 -0.018430  0.082227  0.260154  0.096546
# words_a1  -0.205286  1.000000 -0.369729 -0.577213 -0.762104 -0.511128
# words_a2  -0.018430 -0.369729  1.000000 -0.045488 -0.047032 -0.143426
# words_b1   0.082227 -0.577213 -0.045488  1.000000  0.232315  0.156899
# words_b2   0.260154 -0.762104 -0.047032  0.232315  1.000000  0.378525
# words_c1   0.096546 -0.511128 -0.143426  0.156899  0.378525  1.000000
# words_c2   0.112037 -0.251865 -0.068190  0.108819  0.253723  0.221890
# text_cefr -0.231990  0.268869  0.034151 -0.073834 -0.307060 -0.256640
#
#            words_c2  text_cefr
# uniq       0.112037  -0.231990
# words_a1  -0.251865   0.268869
# words_a2  -0.068190   0.034151
# words_b1   0.108819  -0.073834
# words_b2   0.253723  -0.307060
# words_c1   0.221890  -0.256640
# words_c2   1.000000  -0.154955
# text_cefr -0.154955   1.000000

# %%
features_cefr_as_num = features.copy()
cefr_to_num = {
    'A1': 0,
    'A2': 0,
    'B1': 1,
    'B2': 0,
    'C1': 0,
    'C2': 0
}

features_cefr_as_num['text_cefr'] = features['text_cefr'].map(cefr_to_num)
features_cefr_as_num.corr()
# Out:
#                uniq  words_a1  words_a2  words_b1  words_b2  words_c1  \
# uniq       1.000000 -0.205286 -0.018430  0.082227  0.260154  0.096546
# words_a1  -0.205286  1.000000 -0.369729 -0.577213 -0.762104 -0.511128
# words_a2  -0.018430 -0.369729  1.000000 -0.045488 -0.047032 -0.143426
# words_b1   0.082227 -0.577213 -0.045488  1.000000  0.232315  0.156899
# words_b2   0.260154 -0.762104 -0.047032  0.232315  1.000000  0.378525
# words_c1   0.096546 -0.511128 -0.143426  0.156899  0.378525  1.000000
# words_c2   0.112037 -0.251865 -0.068190  0.108819  0.253723  0.221890
# text_cefr  0.008868  0.035059  0.011315  0.015137 -0.014605 -0.126277
#
#            words_c2  text_cefr
# uniq       0.112037   0.008868
# words_a1  -0.251865   0.035059
# words_a2  -0.068190   0.011315
# words_b1   0.108819   0.015137
# words_b2   0.253723  -0.014605
# words_c1   0.221890  -0.126277
# words_c2   1.000000  -0.058849
# text_cefr -0.058849   1.000000

# %%
features_cefr_as_num = features.copy()
cefr_to_num = {
    'A1': 0,
    'A2': 0,
    'B1': 0,
    'B2': 1,
    'C1': 0,
    'C2': 0
}

features_cefr_as_num['text_cefr'] = features['text_cefr'].map(cefr_to_num)
features_cefr_as_num.corr()
# Out:
#                uniq  words_a1  words_a2  words_b1  words_b2  words_c1  \
# uniq       1.000000 -0.205286 -0.018430  0.082227  0.260154  0.096546
# words_a1  -0.205286  1.000000 -0.369729 -0.577213 -0.762104 -0.511128
# words_a2  -0.018430 -0.369729  1.000000 -0.045488 -0.047032 -0.143426
# words_b1   0.082227 -0.577213 -0.045488  1.000000  0.232315  0.156899
# words_b2   0.260154 -0.762104 -0.047032  0.232315  1.000000  0.378525
# words_c1   0.096546 -0.511128 -0.143426  0.156899  0.378525  1.000000
# words_c2   0.112037 -0.251865 -0.068190  0.108819  0.253723  0.221890
# text_cefr  0.183207 -0.137783  0.004358  0.077763  0.149536  0.061007
#
#            words_c2  text_cefr
# uniq       0.112037   0.183207
# words_a1  -0.251865  -0.137783
# words_a2  -0.068190   0.004358
# words_b1   0.108819   0.077763
# words_b2   0.253723   0.149536
# words_c1   0.221890   0.061007
# words_c2   1.000000   0.016247
# text_cefr  0.016247   1.000000

# %%
features_cefr_as_num = features.copy()
cefr_to_num = {
    'A1': 0,
    'A2': 0,
    'B1': 0,
    'B2': 0,
    'C1': 1,
    'C2': 0
}

features_cefr_as_num['text_cefr'] = features['text_cefr'].map(cefr_to_num)
features_cefr_as_num.corr()
# Out:
#                uniq  words_a1  words_a2  words_b1  words_b2  words_c1  \
# uniq       1.000000 -0.205286 -0.018430  0.082227  0.260154  0.096546
# words_a1  -0.205286  1.000000 -0.369729 -0.577213 -0.762104 -0.511128
# words_a2  -0.018430 -0.369729  1.000000 -0.045488 -0.047032 -0.143426
# words_b1   0.082227 -0.577213 -0.045488  1.000000  0.232315  0.156899
# words_b2   0.260154 -0.762104 -0.047032  0.232315  1.000000  0.378525
# words_c1   0.096546 -0.511128 -0.143426  0.156899  0.378525  1.000000
# words_c2   0.112037 -0.251865 -0.068190  0.108819  0.253723  0.221890
# text_cefr  0.156753 -0.299883  0.047451  0.135051  0.279176  0.202560
#
#            words_c2  text_cefr
# uniq       0.112037   0.156753
# words_a1  -0.251865  -0.299883
# words_a2  -0.068190   0.047451
# words_b1   0.108819   0.135051
# words_b2   0.253723   0.279176
# words_c1   0.221890   0.202560
# words_c2   1.000000   0.139911
# text_cefr  0.139911   1.000000

# %%
features_cefr_as_num = features.copy()
cefr_to_num = {
    'A1': 0,
    'A2': 0,
    'B1': 0,
    'B2': 0,
    'C1': 0,
    'C2': 1
}

features_cefr_as_num['text_cefr'] = features['text_cefr'].map(cefr_to_num)
features_cefr_as_num.corr()
# Out:
#                uniq  words_a1  words_a2  words_b1  words_b2  words_c1  \
# uniq       1.000000 -0.205286 -0.018430  0.082227  0.260154  0.096546
# words_a1  -0.205286  1.000000 -0.369729 -0.577213 -0.762104 -0.511128
# words_a2  -0.018430 -0.369729  1.000000 -0.045488 -0.047032 -0.143426
# words_b1   0.082227 -0.577213 -0.045488  1.000000  0.232315  0.156899
# words_b2   0.260154 -0.762104 -0.047032  0.232315  1.000000  0.378525
# words_c1   0.096546 -0.511128 -0.143426  0.156899  0.378525  1.000000
# words_c2   0.112037 -0.251865 -0.068190  0.108819  0.253723  0.221890
# text_cefr  0.131861 -0.416035 -0.061575  0.180783  0.420738  0.420252
#
#            words_c2  text_cefr
# uniq       0.112037   0.131861
# words_a1  -0.251865  -0.416035
# words_a2  -0.068190  -0.061575
# words_b1   0.108819   0.180783
# words_b2   0.253723   0.420738
# words_c1   0.221890   0.420252
# words_c2   1.000000   0.258953
# text_cefr  0.258953   1.000000

# %%
features_cefr_as_num
# Out:
#           uniq  words_a1  words_a2  words_b1  words_b2  words_c1  words_c2  \
# 0     0.353982  0.606250  0.200000  0.106250  0.075000  0.006250  0.006250
# 1     0.352584  0.379310  0.228448  0.150862  0.185345  0.051724  0.004310
# 2     0.395745  0.408602  0.193548  0.225806  0.161290  0.010753  0.000000
# 3     0.393103  0.429825  0.166667  0.175439  0.157895  0.061404  0.008772
# 4     0.413374  0.573529  0.139706  0.102941  0.139706  0.036765  0.007353
# ...        ...       ...       ...       ...       ...       ...       ...
# 1489  0.354108  0.376000  0.192000  0.128000  0.240000  0.048000  0.016000
# 1490  0.439338  0.393305  0.205021  0.121339  0.225941  0.050209  0.004184
# 1491  0.369748  0.458333  0.155303  0.162879  0.132576  0.087121  0.003788
# 1492  0.423729  0.410909  0.167273  0.163636  0.185455  0.065455  0.007273
# 1493  0.462366  0.348837  0.170543  0.131783  0.240310  0.085271  0.023256
#
#       text_cefr
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 1489          1
# 1490          1
# 1491          1
# 1492          1
# 1493          1
#
# [1494 rows x 8 columns]

# %% [markdown]
# Model

# %%
import tensorflow as tf

# %%
model_features = features_cefr_as_num.drop(columns=["text_cefr"]).to_numpy()
model_targets = features_cefr_as_num.text_cefr.to_numpy()

dataset = tf.data.Dataset.from_tensor_slices((model_features, model_targets))

train_prop = 0.8

dataset = dataset.shuffle(buffer_size=len(model_features))

dataset_train = dataset.take(int(train_prop * len(model_features)))
dataset_test = dataset.skip(int(train_prop * len(model_features)))

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MSE
from tensorflow.keras.metrics import MAE
from tensorflow.keras.callbacks import EarlyStopping

# %%
EPOCHS = 1000
LEARNING_RATE = 0.05
BATCH = 32

dataset_train = dataset_train.batch(BATCH)
dataset_test = dataset_test.batch(BATCH)

compile_params={
    "optimizer": Adam(learning_rate=LEARNING_RATE),
    "loss": MSE,
    "metrics": [MAE],

}

# %%
from tensorflow.keras.layers import Dense, InputLayer

# %%
linear_regression = Sequential([
    InputLayer(shape=(7,)),
    Dense(units=1, activation="linear")
])

linear_regression.compile(**compile_params)

# %%
history = linear_regression.fit(
    dataset_train, 
    validation_data= dataset_test,
    epochs = EPOCHS,
    )
# Out:
# Epoch 1/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - loss: 1.9395 - mean_absolute_error: 1.2073 - val_loss: 1.8331 - val_mean_absolute_error: 1.1641
# Epoch 2/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8050 - mean_absolute_error: 1.1567 - val_loss: 1.6291 - val_mean_absolute_error: 1.0930
# Epoch 3/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6513 - mean_absolute_error: 1.0859 - val_loss: 1.4956 - val_mean_absolute_error: 1.0356
# Epoch 4/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - loss: 1.5236 - mean_absolute_error: 1.0340 - val_loss: 1.3869 - val_mean_absolute_error: 1.0036
# Epoch 5/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3871 - mean_absolute_error: 0.9629 - val_loss: 1.2904 - val_mean_absolute_error: 0.9171
# Epoch 6/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3040 - mean_absolute_error: 0.9373 - val_loss: 1.0091 - val_mean_absolute_error: 0.8069
# Epoch 7/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2821 - mean_absolute_error: 0.9286 - val_loss: 1.2696 - val_mean_absolute_error: 0.9148
# Epoch 8/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1890 - mean_absolute_error: 0.8773 - val_loss: 1.3162 - val_mean_absolute_error: 0.9051
# Epoch 9/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1543 - mean_absolute_error: 0.8535 - val_loss: 1.1645 - val_mean_absolute_error: 0.8772
# Epoch 10/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2079 - mean_absolute_error: 0.8709 - val_loss: 1.2268 - val_mean_absolute_error: 0.8757
# Epoch 11/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1559 - mean_absolute_error: 0.8367 - val_loss: 1.0458 - val_mean_absolute_error: 0.8229
